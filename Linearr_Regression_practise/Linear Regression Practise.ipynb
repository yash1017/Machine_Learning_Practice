# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('USA_Housing.csv')

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %% [markdown]
# spliting data into train data and test data

# %%
x=df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms', 'Avg. Area Number of Bedrooms', 'Area Population']]

y=df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4,random_state=101)

# %% [markdown]
# training the model

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()

lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Evaluating the model

# %%
lm.intercept_
# Out:
# -2640159.79685191

# %%
coeff_df = pd.DataFrame(lm.coef_,x.columns,columns=['coefficient'])

# %%
coeff_df
# Out:
#                                 coefficient
# Avg. Area Income                  21.528276
# Avg. Area House Age           164883.282027
# Avg. Area Number of Rooms     122368.678027
# Avg. Area Number of Bedrooms    2233.801864
# Area Population                   15.150420

# %% [markdown]
# Predicting the model

# %%
predictions = lm.predict(x_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test - predictions),bins=50)
# Out:
# C:\Users\yaswa\AppData\Local\Temp\ipykernel_23536\2993172339.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test - predictions),bins=50)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
from sklearn import metrics

# %%
print(metrics.mean_absolute_error(predictions,y_test))
# Out:
# 82288.22251914954

# %%
metrics.mean_squared_error(predictions,y_test)
# Out:
# 10460958907.2095

# %%
np.sqrt(metrics.mean_squared_error(predictions,y_test))
# Out:
# 102278.82922291152

# %% [markdown]
# Playing with same model again

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.plot.hist(x='Avg. Area House Age',y='Price',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.kdeplot(x=df['Price'],y=df['Avg. Area House Age'])
# Out:
# <Axes: xlabel='Price', ylabel='Avg. Area House Age'>

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
a=df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]
b=df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
a_train,a_test,b_trian,b_test = train_test_split(a,b,test_size=0.5,random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
jk= LinearRegression()

# %%
jk.fit(a_train,b_trian)
# Out:
# LinearRegression()

# %%
jk.intercept_
# Out:
# -2654038.561914619

# %%
jk_df = pd.DataFrame(jk.coef_,x.columns,columns=['coefficient'])

# %%
jk_df
# Out:
#                                 coefficient
# Avg. Area Income                  21.742854
# Avg. Area House Age           165414.111149
# Avg. Area Number of Rooms     120178.003729
# Avg. Area Number of Bedrooms    2707.476251
# Area Population                   15.379529

# %%
df_jk = pd.DataFrame(jk.coef_,x.columns,columns=['coefficient'])

# %%
df_jk
# Out:
#                                 coefficient
# Avg. Area Income                  21.742854
# Avg. Area House Age           165414.111149
# Avg. Area Number of Rooms     120178.003729
# Avg. Area Number of Bedrooms    2707.476251
# Area Population                   15.379529

# %%
df.plot()
# Out:
# <Axes: >

# %%
predictions = jk.predict(x_test)

# %%
plt.scatter(predictions,y_test)

# %%
sns.distplot(y_test - predictions)
# Out:
# C:\Users\yaswa\AppData\Local\Temp\ipykernel_23536\1181080564.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test - predictions)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(predictions,y_test)
# Out:
# 82239.77989535403

# %%
metrics.mean_squared_error(predictions,y_test)
# Out:
# 10435685228.895527

# %%
np.sqrt(metrics.mean_squared_error(predictions,y_test))
# Out:
# 102155.20167321646
